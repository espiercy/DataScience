# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# ###Passenger ID
#
# <li> Categorical v. Continuous: Calling this variable continuous causes some problems. For example, why would I compute the mean or the standard deviation of this variable? Calling it categorical leads to a different set of problems, but that would be a slightly more accurate depiction, since the passengerID is essentially a label as opposed to an amount of something.
#
# <li> Missing Values?: No. By definition, a passenger on this list is assigned a Passenger ID.
#
# <li> Notes: There doesn't seem to be a reason to continue exploration on this variable. I suppose if I were curious I could treat it as continuous and see if there is some correlation between Passenger IDs and boarding location or cabin number, but for cabin at least it looks like there is simply too little data to continue. Additionally, a histogram wouldn't show us a great deal, except that each passenger is assigned a single passenger ID.

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# dtype: int64

# %% [markdown]
# ###Survived
# <li> Categorical v. Continuous: Categorical. This variable could have just as easily been a string assignment.
# <li> Missing Values: none, although there are likely slight inaccuracies. It isn't hard to imagine that at least some of the people who were listed as dead on the Titanic in fact survived. Then again, I have no way of pursuing that idea at present, so we'll assume the data is accurate.

# %%
df.Survived.value_counts().plot(kind='bar')

# %% [markdown]
# The 0's represent deaths, 1's represent survivors. This is pretty much the same as was shown by our demonstration. A majority of the people on the boat died. About 38.384% survived.

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# dtype: int64

# %%
df.Pclass.value_counts().plot(kind= 'bar')

# %% [markdown]
# ###Pclass
#
# <li>Categorical v. Continuous: Categorical. This data represents passenger class, which, again, could just as easily be assigned a char or string (such as "first, second...etc."
# <li>Missing Vals?: No, this information is present. This is an important piece of data when trying to determine whether a passenger lives or dies. The passenger class should be indicative of social status, which has been said to have played an infamous role in the determination of the Titanic survivors. As one would expect, most passengers within the sample fall into Pclass 3 (491 total). I am, however, somewhat surprised that this sample contains more first class passengers than second. After doing a brief internet search, it appears as though the second-class tickets were reserved for servants. That would explain it.

# %% [markdown]
# ###Sex
# <li> Categorical v. Continuous: Categorical. We saw this in the demonstration, and it is somewhat more clear-cut than the previous variables.
# <li> Missing Values?: No.

# %%
df.Sex.value_counts().plot(kind='bar')

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# dtype: int64

# %% [markdown]
# I suppose I should mention here that I've been using the isnull() function to test to see if there are missing values from any variable. Since none have occured, I simply remove the blank chart.

# %% [markdown]
# ###Age
# <li> Categorial v. Continuous: Continuous

# %% [markdown]
# <li> Missing Values?: Yes, and quite a few:

# %%
df[df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %% [markdown]
# There are 177 ages missing from the data.

# %%
177/891.0
# Out:
# 0.19865319865319866

# %% [markdown]
# Nearly 20% of our passengers are missing age data. That really seems like it could skew attempts to do anything with age.

# %%
df.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# dtype: float64

# %% [markdown]
# <li>The minimum is...0.42? What on Earth is that? Did someone literally list their child's age as 0.42?
# <li>The maximum is 80.
# <li>The mean age is roughly 29.7
# <li>The standard deviation is roughly 14.53

# %%
df.Age.value_counts()
# Out:
# 24    30
# 22    27
# 18    26
# 28    25
# 30    25
# 19    25
# 21    24
# 25    23
# 36    22
# 29    20
# 32    18
# 35    18
# 27    18
# 26    18
# 16    17
# ...
# 53.00    1
# 70.50    1
# 14.50    1
# 0.92     1
# 74.00    1
# 36.50    1
# 80.00    1
# 12.00    1
# 55.50    1
# 34.50    1
# 24.50    1
# 66.00    1
# 23.50    1
# 0.67     1
# 20.50    1
# Length: 88, dtype: int64

# %% [markdown]
# Ok, well I did that to see what some of the Age data looked like. I guess fractions are present afterall.

# %%
df.Age.hist()

# %% [markdown]
# Much better idea of what's going on age-wise. Also a pretty respectable distribution.

# %% [markdown]
# ###SibSp
# <li> Categorical v. Continuous: Good question. Oddly enough, I looked up this abbreviation on google and got back definitions for parch. That puts me in a bind, because that happens to be the very next variable for this EDA, which means a)I have no idea what it is, and b)I know just enough to know I really ought to keep looking. Okay well that was easy. The answer was on kaggle it's the number of siblings and spouses aboard. That's fairly continuous.

# %%
df[df.SibSp.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# <li>Missing Values?: No, this information is completely intact.

# %%
df.SibSp.describe()
# Out:
# count    891.000000
# mean       0.523008
# std        1.102743
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        8.000000
# dtype: float64

# %% [markdown]
# The minimum for SibSp is 0. The max is 8. The mean was roughly 0.523. The standard deviation is about 1.103

# %%
df.SibSp.hist()

# %% [markdown]
# Not a very standard curve at all. Most passengers had no siblings or spouses aboard. I do find the passenger(s) with eight siblings/spouses interesting. Presumably, this is a family with six children. Wasn't there a scene in the movie with this group? After I've finished the initial EDAs I'm going to look them up directly to see how they did, although I already see a Ms. Sage with 8 family members did not survive.

# %% [markdown]
# ###Parch
# <li>Continuous v. Categorical: This is the number of parents/children aboard. It is continuous

# %% [markdown]
# <li>Missing Data?:

# %%
df[df.Parch.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# Nope. Like SibSp above, this data is complete.

# %%
df.Parch.describe()
# Out:
# count    891.000000
# mean       0.381594
# std        0.806057
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        6.000000
# dtype: float64

# %% [markdown]
# This data is very similar to SibSp above. The minimum is 0, the max is 6 (who, as it happens, are exactly the children I'm looking for from SibSp above). The mean is roughly 0.3816, with a standard deviation of about 0.806

# %%
df.Parch.hist()

# %% [markdown]
# Yes, pretty similar to the data for SibSp, as one would expect.

# %% [markdown]
# ###Ticket
# <li>Categorical v. continuous: Not 100% certain on this, but due to the seeming randomness in the visible data, and the presence of alphabetical characters, this looks similar to PassengerID in that each appears to have their own ticket number. That would not be surprising, but I feel obligated to check.

# %%
df.Ticket.describe()
# Out:
# count          891
# unique         681
# top       CA. 2343
# freq             7
# dtype: object

# %% [markdown]
# Where this markdown is now, I attempted to do a histogram just to see what would happen. This variable is categorical beyond a doubt, however.

# %%
df.Ticket.value_counts().plot(kind='bar')

# %% [markdown]
# I could tell from how many unique tickets there were that this would be a worthless graph. I just wanted to see what would happen. Oh, I forgot to check missing values, but the count adds up to 891, so that means it's complete.

# %% [markdown]
# ###Fare
# <li>Categorical v. Continuous: Continuous. To me this is the most interesting set of data present. This should be the strongest indicator as to whether wealth had anything to do with survival rate.
# <li>Missing Values?:

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# No missing data for fares.

# %%
df.Fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# dtype: float64

# %% [markdown]
# Minimum is 0 (we saw an explanation for that during the demonstration).

# %% [markdown]
# The maximum was 512.33. That was an extraordinary amount of money to pay for a single ticket back then. The mean was about 30.20, and the standard deviation is about 49.69. That seems like a fairly large standard deviation to have for a mean that's only around 32, but I'm rusty on my stats. I also discovered that markdowns do not like dollar signs.

# %%
df.Fare.hist()

# %% [markdown]
# Here's the histogram of fares. I came to a realization: so few people paid high amounts for their tickets, that I might not be able to determine survival rate based on the ticket price. I do think, however, that I will simply measure the survival rate of everyone who paid below average against everyone who paid above. That's really the closest I can come to, and it might show something.

# %% [markdown]
# ###Cabin
# <li>Categorical v. Continuous: Categorical. I already noticed that a single passenger actually had three adjacent cabins.
# <li>Missing Values?: Yes, and very many. Let's get an actual number:

# %%
df[df.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %% [markdown]
# The vast majority of passenger data are missing this information. Not a good tool to build a model with, I presume. I wonder why that's the case? Could the passenger manifest have gone down with the ship or some other such chicanery?

# %% [markdown]
# ###Embarked
# <li>Categorical v. Continuous: categorical. This answer did not materialize so easily on kaggle, but we can still learn a few things about it.
# <li>Missing Values?:

# %%
df[df.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex  Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female   38      0      0  113572    80   B28      NaN
# 829  female   62      0      0  113572    80   B28      NaN

# %% [markdown]
# Missing exactly two values, but look how interesting! Same ticket number, same fare, same cabin. They traveled together, according to the Encyclopedia Titanica (a real, internet thing). The entry also says that Mrs. George Nelson embarked first in South Hampton, which might be "S." I supposed I could go back and clean those entries, but they aren't very significant to what I want to know about this data.

# %% [markdown]
# ###Further Questions:
# <li> Is there a relation between fare and survival rate? For this analysis I'm going to divide up the data between those who paid below and up to the average ticket fare (32) and those who paid more, and compare those survival rates.

# %%
fig, axs = plt.subplots(1,2)
df[df.Fare<=32].Survived.value_counts().plot(kind='barh', ax=axs[0] , title = "Under 32") 
df[df.Fare>32].Survived.value_counts().plot(kind='barh', ax=axs[1] ,  title = "Over 32")

# %% [markdown]
# The amount of people who paid more than 32 pounds(?) is much smaller, but there still appears to be a strong correlation between Fare price and survival chances.

# %% [markdown]
# <li>What happened to the family of eight?

# %%
df[df.SibSp==8]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %% [markdown]
# Well, they all have the same last names. None of them survived. Can't help but notice that there are only seven listed here, and none of their ages are available, so that makes things a little more difficult. From the E.T. again: Master Thomas Henry Sage boarded the Titanic at Southampton as a third class passenger together with her [sic] parents and siblings: Stella, George, Douglas, Frederick, Dorothy, William, Constance and Ada.
#
# The entire family died in the disaster. Thomas' body, if recovered, was never identified.

# %% [markdown]
# We've accounted for Thomas, Stella, George, Douglas, Frederick, Dorothy, and Constance. William appears to be unaccounted for in this data.
